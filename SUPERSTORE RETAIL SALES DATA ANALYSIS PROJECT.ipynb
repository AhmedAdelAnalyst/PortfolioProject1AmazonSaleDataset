# %% [markdown]
# SUPERSTORE RETAIL SALES DATA ANALYSIS PROJECT

# %% [markdown]
# Retail stores play a crucial role in the everyday life of modern people. Retailers enable consumers to access a wide variety of products and services worldwide. The retail business helps support the country’s economy and create additional workplaces.
# In pursue of knowledge and understanding of which products, regions, categories and customer segments a company should target or avoid, I search and selected an appropriate dataset on kaggle which will match a standard superstore requirement. I'll use python jupyter notebook for the analysis and Tableau public for the visualisation.

# %%
# Import libraries and alias for easy reading
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
# Read in the Superstore Sales Dataset.
df = pd.read_csv(r'C:\Users\Maeshmallow\Desktop\portfolio\SuperstoreSalesDataset.csv')

# %%
# Inspect the first 10 rows.
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# ...

# %%
# Inspect the last 10 rows of dataset
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
# Inspect the number of rows and colums in he dataset.
df.shape
# Out:
# (9800, 18)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# check any duplicates in he dataset and drop it .
df.drop_duplicates().shape
# Out:
# (9800, 18)

# %%
# Get more information about the data, including data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
#check for null values and sum it 
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
#fill null values in each colume
df['Postal Code'] = df['Postal Code'].fillna('Unknown')
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
#check for types of data columes 
print(df.dtypes)
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code       object
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# dtype: object

# %%
# Get descriptive statistics summary
df.describe(include = "all")
# Out:
#              Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# count   9800.000000            9800        9800        9800            9800
# unique          NaN            4922        1230        1326               4
# top             NaN  CA-2018-100111  05/09/2017  26/09/2018  Standard Class
# freq            NaN              14          38          34            5859
# mean    4900.500000             NaN         NaN         NaN             NaN
# std     2829.160653             NaN         NaN         NaN             NaN
# min        1.000000             NaN         NaN         NaN             NaN
# 25%     2450.750000             NaN         NaN         NaN             NaN
# 50%     4900.500000             NaN         NaN         NaN             NaN
# 75%     7350.250000             NaN         NaN         NaN             NaN
# max     9800.000000             NaN         NaN         NaN             NaN
#
# ...

# %% [markdown]
# 1. Which Category is Best Selling?

# %%
# Group sales by category
category_analysis = pd.DataFrame(df.groupby(['Category'])[['Sales']].sum())
category_analysis
# Out:
#                        Sales
# Category
# Furniture        728658.5757
# Office Supplies  705422.3340
# Technology       827455.8730

# %%
# Plot Bar Plot
sns.set_theme(style="whitegrid")
sns.barplot(data = category_analysis, x = category_analysis.index, y = category_analysis.Sales, palette = "muted")
plt.title("sales by category")
plt.show()

# %% [markdown]
# 2. What are the Best Selling Sub-Category?

# %%
# Group by sub-category
subcat_analysis = pd.DataFrame(df.groupby(['Sub-Category'])[['Sales']].sum())# Sort by descending order according to sales
subcat_sales = pd.DataFrame(subcat_analysis.sort_values('Sales', ascending = False))
subcat_sales
# Out:
#                     Sales
# Sub-Category
# Phones        327782.4480
# Chairs        322822.7310
# Storage       219343.3920
# Tables        202810.6280
# Binders       200028.7850
# Machines      189238.6310
# Accessories   164186.7000
# Copiers       146248.0940
# Bookcases     113813.1987
# Appliances    104618.4030
# Furnishings    89212.0180
# Paper          76828.3040
# Supplies       46420.3080
# Art            26705.4100
# Envelopes      16128.0460
# Labels         12347.7260
# Fasteners       3001.9600

# %%
# Plot Bar Plot for Top Selling Sub-Category
sns.set_theme(style="whitegrid")
sns.barplot(data = subcat_sales, y = subcat_sales.index, x = subcat_sales.Sales, palette = "muted")
plt.title("Top Selling Sub-Category")
plt.show()

# %%
segment_analysis = pd.DataFrame(df.groupby(['Segment'])[['Sales']].sum())
segment_analysis
# Out:
#                     Sales
# Segment
# Consumer     1.148061e+06
# Corporate    6.884941e+05
# Home Office  4.249822e+05

# %%
# Plot Bar Plot
sns.set_theme(style="whitegrid")
sns.barplot(data = segment_analysis, x = segment_analysis.index, y = segment_analysis.Sales, palette = "rocket")
plt.title("Customer Segment Sales")
plt.show()

# %% [markdown]
# Which is the Preferred Ship Mode?

# %%
shipmode_analysis = pd.DataFrame(df.groupby(['Ship Mode'])[['Sales']].sum())
shipmode_analysis
# Out:
#                        Sales
# Ship Mode
# First Class     3.455723e+05
# Same Day        1.252190e+05
# Second Class    4.499142e+05
# Standard Class  1.340831e+06

# %%
# Plot Bar Plot
sns.set_theme(style="whitegrid")
sns.barplot(data = shipmode_analysis, x = shipmode_analysis.index, y = shipmode_analysis.Sales, palette = "rocket")
plt.title("Customer Segment Sales")
plt.show()

# %% [markdown]
# 6. Which Region is the Highest In Sales?

# %%
region_analysis = pd.DataFrame(df.groupby(['Region'])['Sales'].sum().reset_index())
region_analysis
# Out:
#     Region        Sales
# 0  Central  492646.9132
# 1     East  669518.7260
# 2    South  389151.4590
# 3     West  710219.6845

# %%
# Plot Pie Chart
explode = [0, 0, 0, 0.1]
plt.pie(region_analysis.Sales, labels = region_analysis.Region , startangle = 90, autopct = "%1.0f%%", explode = explode, shadow = True)
plt.title("Most Profitable by Region")
plt.show()
